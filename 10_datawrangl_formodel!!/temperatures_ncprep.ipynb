# %%
import xarray as xr
import pandas as pd
import geopandas as gpd
import glob
import os

import matplotlib.pyplot as plt

# %% [markdown]
# in this notebook varya is trying to calculate the climatic (temperature) parameters for the centroid (wgs) coordinates of the catchments
#
# #### to do here (for the "last" 30 years 1990-2021):
#
# - read the table with coordinates
# - select only needed points in each file (loop through)
# - calculate the thing (loop? - when needed i guess)

# %%
# # temperature parameters of interest: 

# 1. Mean annual 
# 2. Jan temp mean 
# 3. July temp mean 
# 4. How many times over 0 - frost thaw cycles(?)  
# 5. Mean monsoon (no monsoon?)  
# 6. Monthly average -> cv (std/average) 
# 7. Permafrost -> part of the year that is lower then -2 (or smth) - or some measure to convert air temp to surface temp 
# 8. (Or part of the year when its close) 




# # 1. get coordinates:
# '''(NB: be carefil with x and y) 
# x - 85, y - 28
# longitude - 85, latitude - 28 ''' 

# lats = catchments.y_wgs
# lons = catchments.x_wgs

# %% [markdown]
# ### 0. catchments and coordinates

# %%
table = pd.read_csv('morphometrical_params.csv', sep = ';', index_col = 0)
table_coords = table[['x_wgs', 'y_wgs']]

# %%
# table.head()
table.columns
# Out:
# Index(['DN', 'target', 'Name', 'x_centroid', 'y_centroid', 'area_m',
#        'perimeter', 'glaciersum', 'mean_elevation', 'median_elevation',
#        'std_elevation', 'min_elevation', 'max_elevation', 'range_elevation',
#        'variance_elevation', 'region', 'region_name', 'mean_slope',
#        'median_slope', 'std_slope', 'min_slope', 'max_slope', 'range_slope',
#        'variance_slope', 'glarea_percent', 'glacier', 'x_wgs', 'y_wgs', 'M',
#        'Rc', 'Cc'],
#       dtype='object')

# %%
table_coords.head()#.columns
# Out:
#     x_wgs   y_wgs
# 0  85.622  28.207
# 1  85.617  28.205
# 2  85.591  28.205
# 3  85.603  28.226
# 4  85.591  28.184

# %% [markdown]
# #### deal with .nc files first: create a file with subset of points for each year. deal with them after

# %%
# %%time

# # loop through:
# # 1. select: 

# # check coords: what is x what is y

# # catch: x - 26 y - 28 
# # (x = median_t2m_regions.longitude, y = median_t2m_regions.latitude,

# # open one .nc to see whats going on 

# lats = table_coords.y_wgs
# lons = table_coords.x_wgs

# testfile = xr.open_dataset('/Users/varyabazilova/Desktop/era5land/temperature2m/temp_2m_year2021.nc')
# ds_sel = testfile.sel(longitude=lons, latitude=lats, method='nearest')#.mean(dim = 'time')
# ds_sel.to_netcdf('/Users/varyabazilova/Desktop/era5land/temperature2m/temp2m_2021_points.nc')
# ds_sel.mean(dim = 'time')

# %% [markdown]
# ### !!! overwrite the coordinates so that they correspond to catchments !!!

# %%
# %%time

# # # do it for every file: 

# lats = table.y_wgs
# lons = table.x_wgs

# path = '/Users/varyabazilova/Desktop/era5land/points_subset_t2m'

# for n, f in enumerate(os.listdir(path)):
#     # read every file: 
#     ds = xr.open_dataset(os.path.join(path, f), decode_coords="all")
#     # overwrite the coordinates (dimentions):
#     ds['longitude'] = lons.values
#     ds['latitude']= lats.values
#     print('overwriting done')
#     # save to new_files:

#     # 1. create a year 
#     year = n + 2011
#     # 2. save to dataset
#     # ds_df.to_csv(path_output + '_temp_{y}.csv'.format(y=year))
#     ds.to_netcdf('/Users/varyabazilova/Desktop/era5land/points_coordinates/'+ '_{y}.nc'.format(y=year))
    
#     print(year)

# %%
# %%time

# # # do it for every file: 

# lats = table.y_wgs
# lons = table.x_wgs

# # path = '/Users/varyabazilova/Desktop/era5land/points_subset_t2m'

# # for n, f in enumerate(os.listdir(path)):
#     # read every file: 
# ds = xr.open_dataset('/Users/varyabazilova/Desktop/era5land/points_subset_t2m/temp2m_1995_points.nc', decode_coords="all")
#     # overwrite the coordinates (dimentions):
# ds['longitude'] = lons.values
# ds['latitude']= lats.values

# # 2. save to dataset
# ds.to_netcdf('/Users/varyabazilova/Desktop/era5land/points_coordinates/_1995.nc')
# Out:
# CPU times: user 57.9 s, sys: 1min 51s, total: 2min 49s
# Wall time: 4min 27s

# %%
### new stuff 

allstuff = xr.open_dataset('/Users/varyabazilova/Desktop/era5land/temperature2m/temp_2m_year1990.nc')

newcoords = xr.open_dataset('/Users/varyabazilova/Desktop/era5land/points_coordinates/_1990.nc')

oldcoords = xr.open_dataset('/Users/varyabazilova/Desktop/era5land/points_subset_t2m/temp2m_1990_points.nc')

# %%
test = xr.open_dataset('/Users/varyabazilova/Desktop/era5land/points_coordinates/_2001.nc')
# test = xr.open_dataset('/Users/varyabazilova/Desktop/era5land/points_subset_t2m/temp2m_1990_points.nc')

# %%
test
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 742, latitude: 742, time: 8760)
# Coordinates:
#   * longitude  (longitude) float64 85.62 85.62 85.59 85.6 ... 78.58 78.59 78.6
#   * latitude   (latitude) float64 28.21 28.2 28.2 28.23 ... 33.65 33.64 33.64
#   * time       (time) datetime64[ns] 2001-01-01 ... 2001-12-31T23:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.5 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Thu Jul 07 19:44:03 2022: cdo splityear temperature_2m_2000...
#     CDO:          Climate Data Operators version 2.0.5 (https://mpimet.mpg.de...

# %%
# newcoords
# oldcoords
allstuff
# allstuff.sel(longitude=[55.1, 55.7], latitude=[54.8, 54.9]).mean(dim='time').to_dataframe().reset_index()

# %%
# lats = table_coords.y_wgs
# lons = table_coords.x_wgs
# df = allstuff.sel(longitude=lons, latitude=lats, method='nearest').mean(dim='time').to_dataframe().reset_index()

# %%
df.head()

# %%
# pvt = df.pivot_table(index='latitude', columns='longitude', values='t2m')
# plt.pcolormesh(pvt.columns, pvt.index, pvt.values)

# %% [markdown]
# #### read new point files

# %% [markdown]
# #### read new point files

# %% [markdown]
# #### read new point files:

# %%
# %%time
points = xr.open_mfdataset('/Users/varyabazilova/Desktop/era5land/points_subset_t2m/*.nc')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/opt/anaconda3/envs/project1/lib/python3.7/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     871
#     872     if not paths:
# --> 873         raise OSError("no files to open")
#     874
#     875     if combine == "nested":
#
# OSError: no files to open

# %%
# %%time

## overwrite dimentions:

points['longitude'] = lons.values
points['latitude']= lats.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'lons' is not defined

# %%
# points.longitude.values

# %% [markdown]
# #### mean anual temperature

# %%
# just mean of all data:
mean = points.mean(dim='time')

# %%
# %%time
# mean.longitude.values

mean.t2m.values.load()

# %%
meant2m = mean.t2m

# %%
meant2m.shape

# %%
# %%time

path = '/Users/varyabazilova/Desktop/era5land/points_subset_t2m'

# compute mean for each year and then means among them all 

# mean_annual = xr.Dataset()
means = pd.DataFrame()

for n, f in enumerate(os.listdir(path)):
    # read every file: 
    ds = xr.open_dataset(os.path.join(path, f), decode_coords="all")
    # select the coordinates: 
    dsmean = ds.mean(dim = 'time')
    # to df:
    df = dsmean.to_dataframe()#.drop_duplicates()    
    print('dataframe done')
    
    # 1. create a year 
    year = n + 1990
    # 2. save to dataset
    df.to_csv('/Users/varyabazilova/Desktop/era5land/points_subset_t2m/mean_{y}.csv'.format(y=year))
    print(year, 'done')

# %%
# %%time
# read all files - years: 1990-2021

path = '/Users/varyabazilova/Desktop/era5land/temperature2m/'


subset = xr.Dataset()

for f in os.listdir(path):
    # read every file: 
    ds = xr.open_dataset(os.path.join(path, f), decode_coords="all")
    # select the coordinates: 
    ds_sel = ds.sel(longitude=lons, latitude=lats, method='nearest')
    # merge all back together 
    subset = xr.merge([subset, ds_sel])

# %%
# mean -> to scv: 
subset = subset.mean(dim = 'time') 
df = subset.to_dataframe()
df.to_csv('/Users/varyabazilova/Desktop/era5land/temperature2m/annual_mean.csv')

# %%
# file = xr.open_dataset('/Users/varyabazilova/Desktop/era5land/temperature2m/temperature_2m_1960.nc', decode_coords="all")

# %%
# file

# %%
# select things 

# calculate things 

# iterate to save to csv (see other notebook where you did that)

# %% [markdown]
# # new test with one file (that works)

# %%
# open daimean.nc (computed with cdo) 
ds = xr.open_dataset('/Users/varyabazilova/Desktop/era5land/daymean_temp/daymean_temp_1990.nc')

# %%
# mean vallues 
dsmean = ds.mean(dim = 'time')

# %%
# select points 

lats = table.y_wgs
lons = table.x_wgs

dsmeansel = dsmean.sel(longitude=lons, latitude=lats, method='nearest')

# overwrite coord (like in an example from bas)
dsmeansel['longitude'] = lons.values
dsmeansel['latitude']= lats.values

# %%
# chack it out
# dsmeansel

dsmeansel_df = dsmeansel.to_dataframe() # dimentions: number of catchments squared (742**2)

# %%
dsmeansel_df = dsmeansel_df.reset_index()

# %%
dsmeansel_df.head()
dsmeansel_df_renamed = dsmeansel_df.rename(columns = {'longitude': 'x_wgs', 'latitude': 'y_wgs'})

# %%
# dsmeansel_df_renamed.head()
# table.head()

tableclim = table.merge(dsmeansel_df_renamed, on=['x_wgs', 'y_wgs'], how='left').drop_duplicates()

# %%
# Out:
#       DN  target                                Name   x_centroid  \
# 0      2       1                                  DF  6533932.497
# 1      3       1                                  DF  6534113.836
# 3      4       1                                  DF  6533894.325
# 7      5       0  Mixed - new looks FF, vegetated DF  6531952.768
# 8      7       0         FF - lower lef DF remnants?  6535837.722
# ...   ..     ...                                 ...          ...
# 1430  80       1                                  DF  5907050.424
# 1431  81       1                                  DF  5908114.850
# 1432  82       1                                  DF  5908413.450
# 1433  83       1                                  DF  5909758.971
# 1434  84       1                                  DF  5909775.130
#
#        y_centroid       area_m  perimeter  glaciersum  mean_elevation  \
# 0     -500205.440   323908.568   3584.675       0.000     4738.964789
# 1     -500799.045   182483.700   2922.889       0.000     4568.158333
# 3     -503821.445   205294.163   2702.293       0.000     4182.414815
# 7     -502250.739  8413968.867  19907.851    2763.123     4867.525384
# 8     -503989.910   359644.959   3750.121       0.000     4346.589852
# ...           ...          ...        ...         ...             ...
# 1430 -1195549.440  1284828.337   6069.585       0.000     5628.424171
# 1431 -1195174.890  2358816.953   9545.802       0.000     5394.825105
# 1432 -1193969.040  2622176.316  10483.829       0.000     5583.418578
# 1433 -1193073.120  3833933.847  10870.075       0.000     5311.430018
# 1434 -1191633.470  4054668.573  13408.266       0.000     5411.367374
#
#       median_elevation  ...  range_slope  variance_slope  glarea_percent  \
# 0               4764.5  ...    68.675880      189.262607         0.00000
# 1               4594.5  ...    66.178936      239.110864         0.00000
# 3               4179.0  ...    37.792932       58.833395         0.00000
# 7               4886.5  ...    58.829133      129.789809         0.03284
# 8               4321.0  ...    51.812997       91.630189         0.00000
# ...                ...  ...          ...             ...             ...
# 1430            5622.0  ...    46.034376       66.422860         0.00000
# 1431            5370.0  ...    41.928779       96.024781         0.00000
# 1432            5611.0  ...    46.576362       85.444130         0.00000
# 1433            5253.0  ...    46.173264       97.965173         0.00000
# 1434            5366.0  ...    44.557712       87.863658         0.00000
#
#       glacier   x_wgs   y_wgs             M        Rc        Cc         t2m
# 0           0  85.622  28.207  5.082328e+05  0.316762  1.789410  269.163483
# 1           0  85.617  28.205  2.584446e+05  0.268417  1.943889  269.163483
# 3           0  85.591  28.205  2.854492e+05  0.353282  1.694398  269.163483
# 7           1  85.603  28.226  5.212530e+06  0.266785  1.949823  269.163483
# 8           0  85.591  28.184  4.587736e+05  0.321361  1.776559  269.163483
# ...       ...     ...     ...           ...       ...       ...         ...
# 1430        0  78.558  33.661  8.376585e+05  0.438265  1.521275  266.146454
# 1431        0  78.564  33.652  1.752398e+06  0.325296  1.765780  266.146454
# 1432        0  78.576  33.651  1.943176e+06  0.299800  1.839332  266.146454
# 1433        0  78.586  33.639  2.572869e+06  0.407746  1.577181  265.726227
# 1434        0  78.600  33.642  2.575421e+06  0.283413  1.891761  265.726227
#
# [716 rows x 32 columns]
